# %%
import numpy as np
import pandas as pd
import sklearn
import nltk

from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = "/content/drive/MyDrive/Skripsi/Data/datafinallast.xlsx"
df = pd.read_excel(data)
df
# Out:
#                                               full_text  sentimen  \
# 0     Resmi Naik BPJS Kesehatan Ungkap Alasan Penyes...         1
# 1     Ketika belanja di warung tetangga seribu perak...        -1
# 2     @PutraWadapi Akan banyak Potongan salah satuny...         1
# 3     Berita soal iuran BPJS Kesehatan naik per 1 Ja...         1
# 4     pagi-pagi dapet email #BPJSNaik lagi ðŸ˜Œ http...         1
# ...                                                 ...       ...
# 1865  @4nneve @jokowi Rakyat sdh dijajah dgn Kebijak...        -1
# 1866  @aldrin_neil @sudjiwotedjo Dipreteli sebelah m...        -1
# 1867  @febridiansyah @OmbudsmanRI137 Disini problem ...        -1
# 1868  @mrshananto BPJS kesehatan THR 1 bulan gaji ta...         1
# 1869  @110111010010l @msaid_didu Ntar kaya kasus ken...        -1
#
#                                                cleansed  \
# 0     resmi naik bpjs kesehatan ungkap alasan penyes...
# 1     ketika belanja warung tetangga seribu perak ju...
# ...

# %%
df.drop(['full_text','cleansed','tokenized','stemmed','stopwords'], axis=1, inplace=True)
df
# Out:
#       sentimen                                                fix
# 0            1        resmi naik bpjs sehat alas sesuai iur kelas
# 1           -1  belanja warung tetangga ribu perak tawar gigih...
# 2            1  potong salah potong bpjs naik usutpredatorkm u...
# 3            1  berita iur bpjs sehat naik januari rajin tempe...
# 4            1                     pagipagi dapet email bpjsnaik
# ...        ...                                                ...
# 1865        -1  rakyat sdh jajah dgn bijak pro kapitalis impor...
# 1866        -1  pretel belah manaputusan adil naik bpjs aja ak...
# 1867        -1  problem gak rekomendasi laksana presiden laksa...
# 1868         1  bpjs sehat thr gaji tabung emas digital naik gaji
# 1869        -1  ntar kaya naik iur bpjs dah batal ehh dinaikin...
#
# [1870 rows x 2 columns]

# %%
# menentukan kolom x dan y
X = df['fix']
y = df['sentimen'].astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, stratify=y, random_state=0)

# %%
df_train = pd.concat([X_train, y_train], axis = 1).reset_index(drop=True)
df_test = pd.concat([X_test, y_test], axis = 1).reset_index(drop=True)

# %%
print(len(df_train))
# Out:
# 1309

# %%
print(len(df_test))
# Out:
# 561

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = df_train['fix'].apply(lambda x:''.join(x))
vectorizer = CountVectorizer()
X_train_wc = vectorizer.fit_transform(corpus)
X_train_wc
# Out:
# <1309x3856 sparse matrix of type '<class 'numpy.int64'>'
# 	with 16196 stored elements in Compressed Sparse Row format>

# %%
y_train = np.array(df_train['sentimen'])
y_test = np.array(df_test['sentimen'])

# %%
corpus = df_test['fix'].apply(lambda x:''.join(x))
X_test_wc = vectorizer.fit_transform(corpus)

# %%
print("Shape of X_train = {}".format(X_train_wc.shape))
print("Shape of y_train = {}".format(y_train.shape))
print("Shape of X_test = {}".format(X_test_wc.shape))
print("Shape of y_test = {}".format(y_test.shape))
# Out:
# Shape of X_train = (1309, 3856)
# Shape of y_train = (1309,)
# Shape of X_test = (561, 2200)
# Shape of y_test = (561,)

# %%
from sklearn.model_selection import cross_val_score
clf = MultinomialNB()

# %%
from sklearn.metrics import confusion_matrix
Y_pred = cross_val_predict(clf, X_test_wc, y_test, cv = 10)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
#accuracy score
print("accuracy = ")
print(accuracy_score(y_test,Y_pred))

#precision score
print("precision = ")
print(precision_score(y_test,Y_pred, pos_label = 1))

#recall score
print("recall = ")
print(recall_score(y_test,Y_pred, pos_label = 1))

#f1 score
print("f1 score = ")
print(f1_score(y_test,Y_pred, pos_label = 1))

#confusion matrix
print(confusion_matrix(y_test, Y_pred))
# Out:
# accuracy =
# 0.7629233511586453
# precision =
# 0.7315436241610739
# recall =
# 0.8044280442804428
# f1 score =
# 0.7662565905096661
# [[210  80]
#  [ 53 218]]
